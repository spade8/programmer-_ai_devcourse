# %% [markdown]
# # [3주차 - Day5] Weekly Mission
# 3주차 강의를 마치신 것을 축하드립니다! 🎉
#
# 이 미션들은 Mandatory Part(필수 파트)와 Bonus Part(보너스 파트)로 이루어져있습니다.
#
#   - Mandatory Part : 반드시 해결해야 하는 과제
#   - Bonus Part : 추가로 해결할 수 있는 과제
#
# 여러분이 해결할 수 있는 만큼 해결해주세요. 건승을 빕니다! 🙂

# %% [markdown]
# ---
# ## Mission 1. Netfilx and Code

# %% [markdown]
# 호주니는 요즘 넷플릭스를 보는데 심취해있다. 최근 넷플릭스와 협업하는 K-Contents가 늘어가는 것을 보면서 자부심을 느끼는 한편, 넷플릭스에 얼마나 많은 한국 작품이 있는지 궁금해졌다. 호주니를 도와 넷플릭스에 얼마나 많은 한국 작품이 있는지 알아보자.

# %% [markdown]
# ![image.png](attachment:6acf0296-24db-49e3-9897-7e252cf298b9.png)

# %% [markdown]
# ---
#
# ### Mandatory Part
# - [넷플릭스 데이터](https://www.kaggle.com/datasets/shivamb/netflix-shows)가 주어졌을 때, 다음 질문에 답하시오:
# - 한국 작품은 총 얼마나 있는가?
#   - country column을 기준으로 한다.
#   - "South Korea"인 경우만 인정한다. ("US, South Korea"는 인정하지 않음)

# %% [markdown]
#  - 먼저 문제 해결에 필요한 라이브러리를 호출한다.

# %%
import numpy as np 
import pandas as pd

# %% [markdown]
# - 주어진 링크를 통해 `csv` 파일을 다운받고 `pd.read_csv` 메소드를 활용하여 `csv` 파일에 접근한다.

# %%
netflix_data = pd.read_csv("./netflix_titles.csv")
netflix_data
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %% [markdown]
# - 주어진 조건을 활용하여 `country` column이 `South Korea`인 data 만을 이용한 DataFrame을 만든다.

# %%
netflix_korea = netflix_data[netflix_data['country'] == 'South Korea']
netflix_korea
# Out:
#      show_id     type                        title       director  \
# 104     s105  TV Show          Tayo the Little Bus            NaN
# 124     s125  TV Show  Pororo - The Little Penguin            NaN
# 289     s290  TV Show            The Crowned Clown            NaN
# 456     s457  TV Show             Her Private Life            NaN
# 545     s546  TV Show         YooHoo to the Rescue            NaN
# ...      ...      ...                          ...            ...
# 8463   s8464    Movie       The President's Barber  Chan-sang Lim
# 8467   s8468    Movie                   The Prison       Na Hyeon
# 8575   s8576  TV Show              This Is My Love            NaN
# 8613   s8614    Movie               Train to Busan   Sang-ho Yeon
# 8684   s8685  TV Show                      Vroomiz            NaN
#
#                                                    cast      country  \
# 104                          Robyn Slade, Kami Desilets  South Korea
# ...

# %% [markdown]
#  - `len` 함수를 이용하여 한국작품의 갯수를 출력한다.

# %%
print(len(netflix_korea))
# Out:
# 199

# %% [markdown]
# ---
#
# ### Bonus Part
# - [넷플릭스 데이터](https://www.kaggle.com/datasets/shivamb/netflix-shows)가 주어졌을 때, 다음 질문에 답하시오:
# - 가장 많은 작품이 올라간 국가는 어디이고, 얼마나 많은 작품이 있는가?
#   - country column을 기준으로 한다.
#   - 단일 국가인 경우를 기준으로 결과를 구해보자.

# %% [markdown]
#  - 먼저 문제 해결에 필요한 라이브러리를 호출한다.

# %%
import numpy as np 
import pandas as pd 
from collections import Counter

# %% [markdown]
# - 주어진 링크를 통해 `csv` 파일을 다운받고 `pd.read_csv` 메소드를 활용하여 `csv` 파일에 접근한다.

# %%
netflix_data = pd.read_csv("./netflix_titles.csv")
netflix_data
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %% [markdown]
# - 주어진 조건을 활용하여 `country` column의 값이 단일국가인 data 만을 이용한 DataFrame을 만든다.

# %%
not_null = netflix_data[netflix_data['country'].isnull() == False]
single_country_data = not_null[~(not_null['country'].str.contains(","))] 

single_country_data
# Out:
#      show_id     type                          title         director  \
# 0         s1    Movie           Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show                  Blood & Water              NaN
# 4         s5  TV Show                   Kota Factory              NaN
# 8         s9  TV Show  The Great British Baking Show  Andy Devonshire
# 9        s10    Movie                   The Starling   Theodore Melfi
# ...      ...      ...                            ...              ...
# 8800   s8801  TV Show             Zindagi Gulzar Hai              NaN
# 8802   s8803    Movie                         Zodiac    David Fincher
# 8804   s8805    Movie                     Zombieland  Ruben Fleischer
# 8805   s8806    Movie                           Zoom     Peter Hewitt
# 8806   s8807    Movie                         Zubaan      Mozez Singh
#
#                                                    cast         country  \
# ...

# %% [markdown]
# - `Counter` 메소드를 이용하여 `country` column의 값을 기준으로 연산후, 가장 큰 값을 갖는 국가와 그 값을 출력

# %%
count = Counter(single_country_data['country'])
print(count.most_common(1))
# Out:
# [('United States', 2818)]

# %% [markdown]
# ---
# ## Mission 2. 가즈아!

# %% [markdown]
# 서울의 소시민 나일론 마스크는 요즘 가상화폐에 푹 빠져있다. 매일매일 극락과 지옥을 오가는 매운맛에 정신을 못 차리고 있는데, 그의 친구인 호주니는 그에게 정신차리게 하기 위해 비트코인 광풍이 일었던 2017년 한 해의 가격의 변화를 보여주려고 한다. 그런데 매일매일의 데이터를 보여주는 것보다 이것의 추세를 표현해주면 좋겠다는 생각이 들어 Moving Average(이동평균법) 를 도입하고자 한다. 호주니를 도와 마스크씨를 설득해보자.
# ![image.png](attachment:71c7ddd6-f657-4d59-bfde-4a6b1e370e89.png)

# %% [markdown]
# ---
#
# ### Mandatory Part
# [다음 데이터](https://www.kaggle.com/datasets/rishidamarla/bitcoin-prices-20112015) 다음 데이터가 주어졌을 때 2016.6 ~ 2017.6 기간의 5-MA(Moving Average) 비트코인 가격 그래프를 그려주세요.
#
#  - 선의 색깔은 **노란색(#f2a900)** 으로 해야합니다.
#  - x-axis label과 y-axis label은 적절한 텍스트로 추가되어야 합니다.
#  - 이동평균의 기준은 `Open` Column으로 계산합니다.
#  - 이외에도 그래프를 알아보기 쉽게 하기 위한 정보(Text, Facet 등)을 추가하는 것도 좋습니다.
#
# 💡 이동평균(Moving Average)법은 시계열 데이터를 표현하는 데에 많이 사용하는 방법 중 하나입니다.

# %% [markdown]
#  - 먼저 문제 해결에 필요한 라이브러리를 호출한다.

# %%
import numpy as np 
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# - 주어진 링크를 통해 `csv` 파일을 다운받고 `pd.read_csv` 메소드를 활용하여 `csv` 파일에 접근한다.
# - 주어진 날짜 조건에 맞게 DataFrame을 편집한다.
# - Data를 날짜를 기준으로 정렬한후 `index`를 재설정한다.

# %%
bitcoin_data = pd.read_csv("./BitCoin.csv")
bitcoin_data = bitcoin_data[(bitcoin_data['Date']>='2016-06-01') & (bitcoin_data['Date']<'2017-07-01')]
bitcoin_data = bitcoin_data.sort_values('Date')
bitcoin_data.reset_index(inplace=True, drop=True)
bitcoin_data
# Out:
#      Unnamed: 0        Date     Open     High      Low    Close        Volume  \
# 0           625  2016-06-01   431.86   431.86   426.34   429.11  3.404250e+07
# 1           594  2016-06-02   386.59   386.63   372.39   376.52  4.924930e+07
# 2           565  2016-06-03   400.52   411.91   395.78   407.71  9.121250e+07
# 3           534  2016-06-04   424.28   424.53   422.73   423.41  5.909100e+07
# 4           504  2016-06-05   447.94   461.38   447.07   459.60  7.279680e+07
# ..          ...         ...      ...      ...      ...      ...           ...
# 372          88  2017-06-26  2590.57  2615.25  2376.29  2478.45  1.663280e+09
# 373          87  2017-06-27  2478.45  2552.45  2332.99  2552.45  1.489790e+09
# 374          86  2017-06-28  2553.03  2603.98  2484.42  2574.79  1.183870e+09
# 375          85  2017-06-29  2567.56  2588.83  2510.48  2539.32  9.499790e+08
# 376          84  2017-06-30  2539.24  2559.25  2478.43  2480.84  8.602730e+08
#
#       Market Cap
# ...

# %% [markdown]
# - `.to_datetime` 함수를 이용하여 `Date` column의 값을 형변환 해준다.

# %%
bitcoin_data['Date'] = pd.to_datetime(bitcoin_data['Date'])
bitcoin_data
# Out:
#      Unnamed: 0       Date     Open     High      Low    Close        Volume  \
# 0           625 2016-06-01   431.86   431.86   426.34   429.11  3.404250e+07
# 1           594 2016-06-02   386.59   386.63   372.39   376.52  4.924930e+07
# 2           565 2016-06-03   400.52   411.91   395.78   407.71  9.121250e+07
# 3           534 2016-06-04   424.28   424.53   422.73   423.41  5.909100e+07
# 4           504 2016-06-05   447.94   461.38   447.07   459.60  7.279680e+07
# ..          ...        ...      ...      ...      ...      ...           ...
# 372          88 2017-06-26  2590.57  2615.25  2376.29  2478.45  1.663280e+09
# 373          87 2017-06-27  2478.45  2552.45  2332.99  2552.45  1.489790e+09
# 374          86 2017-06-28  2553.03  2603.98  2484.42  2574.79  1.183870e+09
# 375          85 2017-06-29  2567.56  2588.83  2510.48  2539.32  9.499790e+08
# 376          84 2017-06-30  2539.24  2559.25  2478.43  2480.84  8.602730e+08
#
#       Market Cap
# 0     6498830000
# ...

# %% [markdown]
# - 그래프를 그린다.

# %%
ma5 = bitcoin_data['Open'].rolling(window=5).mean()
plt.rc('font', family='Malgun Gothic')
plt.figure(figsize=(15,8))
plt.plot(bitcoin_data['Date'], ma5, color="#f2a900")
plt.title(" MA(Moving Average) 비트코인 가격 그래프")
plt.xlabel("Date")
plt.ylabel("Bitcoin Moving Average")
plt.grid(True, linestyle='--')
plt.show()

# %% [markdown]
# ---
#
#
# ### Bonus Part
#   위에 주어진 데이터와 더불 [다음 데이터](https://www.kaggle.com/datasets/prasoonkottarathil/ethereum-historical-dataset?select=ETH_day.csv)도 주어졌을 때, 2016.6 ~ 2017.6 기간에 해당하는 비트코인의 5-MA 그래프와 이더리움의 5-MA 그래프를 동시에 그려주세요.
#
#  - 선의 색깔은 비트코인 : 노란색(#f2a900), 이더리움 : 검은색(#3c3c3d) 으로 해야합니다.
#  - x-axis label과 y-axis label은 적절한 텍스트로 추가되어야 합니다.
#  - 이동평균의 기준은 Open Column으로 계산합니다.
#  - 이외에도 그래프를 알아보기 쉽게 하기 위한 정보(Text, Facet 등)을 추가하는 것도 좋습니다.

# %% [markdown]
# - 주어진 링크를 통해 `csv` 파일을 다운받고 `pd.read_csv` 메소드를 활용하여 `csv` 파일에 접근한다.
# - 주어진 날짜 조건에 맞게 DataFrame을 편집한다.
# - Data를 날짜를 기준으로 정렬한후 `index`를 재설정한다.
# - `.to_datetime` 함수를 이용하여 `Date` column의 값을 형변환 해준다.

# %%
eth_data = pd.read_csv("./ETH_day.csv")
eth_data = eth_data[(eth_data['Date']>='2016-06-01') & (eth_data['Date']<'2017-07-01')]
eth_data = eth_data.sort_values('Date')
eth_data.reset_index(inplace=True, drop=True)
eth_data['Date'] = pd.to_datetime(eth_data['Date'])
eth_data
# Out:
#           Date  Symbol    Open    High     Low   Close  Volume ETH  \
# 0   2016-06-01  ETHUSD   14.18   14.35   13.54   13.95     6390.06
# 1   2016-06-02  ETHUSD   13.95   14.13   13.82   13.90      942.85
# 2   2016-06-03  ETHUSD   13.90   16.05   13.50   14.02    11426.53
# 3   2016-06-04  ETHUSD   14.02   14.16   13.64   13.86     4330.50
# 4   2016-06-05  ETHUSD   13.86   13.92   13.70   13.91      787.49
# ..         ...     ...     ...     ...     ...     ...         ...
# 390 2017-06-26  ETHUSD  278.73  299.90  210.00  253.00   249076.24
# 391 2017-06-27  ETHUSD  253.00  288.17  210.02  286.21   173179.40
# 392 2017-06-28  ETHUSD  286.21  324.95  260.49  317.59   184030.56
# 393 2017-06-29  ETHUSD  317.59  322.84  285.23  293.80   152271.32
# 394 2017-06-30  ETHUSD  293.80  304.94  270.77  280.80   146545.22
#
#       Volume USD
# 0       89027.81
# 1       13180.38
# 2      157342.19
# 3       59977.39
# 4       10869.67
# ..           ...
# 390  60950252.99
# ...

# %% [markdown]
# - 그래프를 그린다.

# %%
ma5_bitcoin = bitcoin_data['Open'].rolling(window=5).mean()
ma5_eth = eth_data['Open'].rolling(window=5).mean()
plt.rc('font', family='Malgun Gothic')
plt.figure(figsize=(15,8))
plt.plot(bitcoin_data['Date'], ma5_bitcoin, color="#f2a900")
plt.plot(eth_data['Date'], ma5_eth, color="#3c3c3d")
plt.title("MA(Moving Average) 비트코인 & 이더리움 가격 그래프")
plt.xlabel("Date")
plt.ylabel("Moving Average")
plt.grid(True, linestyle='--')
plt.legend(labels=['Bitcoin','Ethereum'])
plt.show()
